# %% [markdown]
# <a href="https://colab.research.google.com/github/miksi0078/BSAI-Python-Track/blob/main/Tasks/03_Python_mini_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 3
#
# Take sentence input.
#
# Print:
#
# unique words
#
# word frequency
#
# (Hint: set + dictionary)

# %%
def words(sent):
    result=[]
    uniquewords={}
    word=""
    for c in sent:
        if c!=" ":
          word+=c
        else:
          result.append(word)
          word=""
    return result
def frequence(words):
  count=0
  for w in words:
    for j in words:
      if w==j:
        count+=1
    if w!=" ":
      print(w," frequence:",count)
      #uniquewords.add(w)
      count=0
sentance=input("Enter any setnace eg (hi hello im miksi):\t")
print(sentance)
sentance+=" "
unique={sentance[0]}
for ch in sentance:
  print(ch)
  if ch!=" ":
    unique.add(ch)
print(unique)
print(words(sentance))
frequence(words(sentance))
#but not handling edge cases like before spaces lots of spaces etc
# Out:
# Enter any setnace eg (hi hello im miksi):	hi hello hi miksi miksi
# hi hello hi miksi miksi
# h
# i
#
# h
# e
# l
# l
# o
#
# h
# i
#
# m
# i
# k
# s
# i
#
# m
# i
# k
# s
# i
#
# {'h', 'k', 'e', 'l', 'o', 's', 'm', 'i'}
# ['hi', 'hello', 'hi', 'miksi', 'miksi']
# hi  frequence: 2
# hello  frequence: 1
# hi  frequence: 2
# miksi  frequence: 2
# miksi  frequence: 2

# %% [markdown]
# enhancement

# %%
def words(sent):
    result = []
    word = ""
    for c in sent:
        if c != " ":
            word += c
        else:
            if word != "":
                result.append(word)
                word = ""
    return result

def frequence(word_list):
    printed = set()   #to creating empty set
    for w in word_list:
        if w not in printed:
            count = 0
            for j in word_list:
                if w == j:
                    count += 1
            print(w, "frequency:", count)
            printed.add(w)

sentence = input("Enter any sentence eg (hi hello im miksi):\t")
print("Original sentence:", sentence)

sentence += " " #ading space if user didnt pprovide after sentance
#chracters set unique one
unique = set()
for ch in sentence:
    if ch != " ":
        unique.add(ch)

print("Unique characters:", unique)

#words extraction
word_list = words(sentence)

print("Words list:", word_list)

#frequence of words
print("Word frequencies:")
frequence(word_list)
# Out:
# Enter any sentence eg (hi hello im miksi):	   hi    hello     hi    hi miksi how are you miksi
# Original sentence:    hi    hello     hi    hi miksi how are you miksi
# Unique characters: {'h', 'y', 'k', 'e', 'l', 'o', 's', 'w', 'm', 'i', 'r', 'a', 'u'}
# Words list: ['hi', 'hello', 'hi', 'hi', 'miksi', 'how', 'are', 'you', 'miksi']
# Word frequencies:
# hi frequency: 3
# hello frequency: 1
# miksi frequency: 2
# how frequency: 1
# are frequency: 1
# you frequency: 1

# %% [markdown]
# proper project type

# %%
def words(sent):
    result = []
    word = ""
    for c in sent:
        if c != " ":
            word += c
        else:
            if word != "":
                result.append(word)
                word = ""
    return result

def frequence(word_list,c):
    printed = set()   #to creating empty set
    for w in word_list:
        if w not in printed:
            count = 0
            for j in word_list:
                if w == j:
                    count += 1
            if c==4:
               print(w, "frequency:", count)
            printed.add(w)
    if c==3:
      return printed
def uniqueChracter(sentence):
  unique = set()
  for ch in sentence:
     if ch != " ":
        unique.add(ch)

  print("Unique characters:", unique)


while True:
   try:
     sentence = input("Enter any sentence eg (hi hello im miksi):\t")
     print("Original sentence:", sentence)
     sentence += " " #ading space if user didnt pprovide after sentance
     break

   except ValueError:
     print("invalid try againg!")
while True:
     choice=0
     print("1 for unique chracter display:\n2 for all words list display:\n3 for unique words display:\n4 for frequences of words:\n5 for exit...")
     try:
        choice=int(input("enter your choice:\t"))
     except ValueError:
        print("invalid choice try againg!")
        break
     if choice==1:
      uniqueChracter(sentance)
     elif choice==2:
      print(words(sentance))
     elif choice==3:
      print(frequence(words(sentance),choice))
     elif choice==4:
       frequence(words(sentance),choice)
     elif choice==5:
      exit()
     else:
      print("invalid choice try again!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13552/678735698.py in <cell line: 0>()
#      35 while True:
#      36    try:
# ---> 37      sentence = input("Enter any sentence eg (hi hello im miksi):\t")
#      38      print("Original sentence:", sentence)
#      39      sentence += " " #ading space if user didnt pprovide after sentance
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
def words(sent):
    result = []
    word = ""

    for c in sent:
        if c != " ":
            word += c
        else:
            if word != "":
                result.append(word)
                word = ""

    return result


def frequence(word_list, c):
    printed = set()

    for w in word_list:
        if w not in printed:
            count = 0
            for j in word_list:
                if w == j:
                    count += 1

            if c == 4:
                print(w, "frequency:", count)

            printed.add(w)

    if c == 3:
        return printed


def uniqueChracter(sentence):
    unique = set()

    for ch in sentence:
        if ch != " ":
            unique.add(ch)

    print("Unique characters:", unique)



while True:
    try:
        sentence = input("Enter any sentence eg (hi hello im miksi): ")
        print("Original sentence:", sentence)
        sentence += " "
        break
    except ValueError:
        print("Invalid try again!")



while True:

    print("\n1 for unique characters")
    print("2 for all words list")
    print("3 for unique words")
    print("4 for word frequencies")
    print("5 for exit")

    try:
        choice = int(input("Enter your choice: "))
    except ValueError:
        print("Invalid choice try again!")
        continue

    if choice == 1:
        uniqueChracter(sentence)

    elif choice == 2:
        print(words(sentence))

    elif choice == 3:
        print(frequence(words(sentence), choice))

    elif choice == 4:
        frequence(words(sentence), choice)

    elif choice == 5:
        print("Program exited.")
        break

    else:
        print("Invalid choice try again!")
# Out:
# Enter any sentence eg (hi hello im miksi): hi hello miksi hi how are you hi
# Original sentence: hi hello miksi hi how are you hi
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: 1
# Unique characters: {'l', 'w', 'k', 'm', 'r', 'i', 'h', 'o', 's', 'y', 'u', 'e', 'a'}
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: 2
# ['hi', 'hello', 'miksi', 'hi', 'how', 'are', 'you', 'hi']
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: 3
# {'hello', 'you', 'hi', 'miksi', 'are', 'how'}
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: 4
# hi frequency: 3
# hello frequency: 1
# miksi frequency: 1
# how frequency: 1
# are frequency: 1
# you frequency: 1
#
# ...

# %%
def words(sent):
    result = []
    word = ""

    for c in sent:
        if c != " ":
            word += c
        else:
            if word != "":
                result.append(word)
                word = ""

    return result


def frequence(word_list, c):
    printed = set()

    for w in word_list:
        if w not in printed:
            count = 0
            for j in word_list:
                if w == j:
                    count += 1

            if c == 4:
                print(w, "frequency:", count)

            printed.add(w)

    if c == 3:
        return printed


def uniqueChracter(sentence):
    unique = set()

    for ch in sentence:
        if ch != " ":
            unique.add(ch)

    print("Unique characters:", unique)



while True:
    try:
        sentence = input("Enter any sentence eg (hi hello im miksi): ")
        print("Original sentence:", sentence)
        sentence += " "
        break
    except ValueError:
        print("Invalid try again!")



while True:

    print("\n1 for unique characters")
    print("2 for all words list")
    print("3 for unique words")
    print("4 for word frequencies")
    print("5 for exit")

    try:
        choice = int(input("Enter your choice: "))
    except ValueError:
        print("Invalid choice try again!")
        continue

    if choice == 1:
        uniqueChracter(sentence)

    elif choice == 2:
        print(words(sentence))

    elif choice == 3:
        print(frequence(words(sentence), choice))

    elif choice == 4:
        frequence(words(sentence), choice)

    elif choice == 5:
        print("Program exited.")
        break

    else:
        print("Invalid choice try again!")
# Out:
# Enter any sentence eg (hi hello im miksi): hi hello
# Original sentence: hi hello
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: 9
# Invalid choice try again!
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: k
# Invalid choice try again!
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: ggjsh
# Invalid choice try again!
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: kvgo9t7`
# Invalid choice try again!
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# 4 for word frequencies
# 5 for exit
# Enter your choice: u12uifdyukg
# Invalid choice try again!
#
# 1 for unique characters
# 2 for all words list
# 3 for unique words
# ...
