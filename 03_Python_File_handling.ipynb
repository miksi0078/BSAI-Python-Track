# %% [markdown]
# <a href="https://colab.research.google.com/github/miksi0078/BSAI-Python-Track/blob/main/03_Python_File_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write to file
with open("data.txt", "w") as f:
    f.write("Python Basics Session 1\n")
    f.write("Mini projects examples\n")

# Read from file
with open("data.txt", "r") as f:
    content = f.read()
print(content)



# Append data
with open("data.txt", "a") as f:
    f.write("\nAdded new lines\n")  # new lines
# Out:
# Python Basics Session 1
# Mini projects examples

# %%
# Write to file
with open("data.txt", "w") as f:
    f.write("Python Basics Session 1\n")
    f.write("Mini projects examples\n")

# Read from file
with open("data.txt", "r") as f:
    content = f.read()
print(content)

with open("poetry.txt","r")as f:
    content=f.read()
    print(content)
# Append data
with open("data.txt", "a") as f:

    f.write(content)          # existing content
    f.write("\nAdded new lines\n")  # new lines
    #poetry file required for running
    """
    Python Basics Session 1
Mini projects examples
#poetry content save as poetry.txt
1. Dil hi to hai na sangâ€‘oâ€‘khisht, dard se bhar na aaye kyun â€” Mirza Ghalib
2. Yeh na thi hamari qismat ke wisalâ€‘eâ€‘yar hota â€” Mirza Ghalib
3. Dilâ€‘eâ€‘nadan tujhe hua kya hai, akhir is dard ki dawa kya hai â€” Mirza Ghalib
4. Hum ko malum hai jannat ki haqiqat lekin â€” Mirza Ghalib
5. Teri soorat se hai alam mein baharon ko sabatt â€” Faiz Ahmed Faiz
6. Nahi nigah mein manzil to justojoo hi sahi â€” Faiz Ahmed Faiz
7. Dil na umeed to nahi nakaam hi to hai â€” Faiz Ahmed Faiz
8. Raat yun dil mein teri khoi hui yaad aayi â€” Faiz Ahmed Faiz
9. Mohabbat karne walon ki tijarat bhi anokhi hoti hai â€” Faiz Ahmed Faiz
10. Aur sukoon aisa hai ke m
"""
# Out:
# Python Basics Session 1
# Mini projects examples
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-463/2059586062.py in <cell line: 0>()
#       9 print(content)
#      10
# ---> 11 with open("poetry.txt","r")as f:
#      12     content=f.read()
#      13     print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'poetry.txt'
