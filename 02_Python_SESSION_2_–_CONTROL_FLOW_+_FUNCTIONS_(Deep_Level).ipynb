# %% [markdown]
# <a href="https://colab.research.google.com/github/miksi0078/BSAI-Python-Track/blob/main/02_Python_SESSION_2_%E2%80%93_CONTROL_FLOW_%2B_FUNCTIONS_(Deep_Level).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IF, ELIF, ELSE (Deep Understanding)
if condition:
    # block
elif condition:
    # block
else:
    # block
#Indentation = structure.
#Python doesn’t use {} like C++
# Out:
#   File "/tmp/ipykernel_392/2141645863.py", line 4
#     elif condition:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
#Everything inside if is evaluated as True or False.
if 5:
    print("Runs")

if 0:
    print("Won't run")
"""
Because:

0 → False

Non-zero → True

Empty string → False

Empty list → False

None → False

🔥 Interview Question:
Explain truthy and falsy values in Python.
"""
# Out:
# Runs
# '\nBecause:\n\n0 → False\n\nNon-zero → True\n\nEmpty string → False\n\nEmpty list → False\n\nNone → False\n\n🔥 Interview Question:\nExplain truthy and falsy values in Python.\n'

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible")
# Out:
# Enter age: 90
# You are eligible to vote

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("A+")
else:
    if marks >= 80:
        print("A")
    else:
        print("Below A")
# Out:
# Enter marks: 80
# A

# %%
if marks >= 90:
    print("A+")
elif marks >= 80:
    print("A")
else:
    print("Below A")
    #better way
# Out:
# A

# %%
age = 20
citizen = True

if age >= 18 and citizen:
    print("Eligible")
    # logical operator inside if
# Out:
# Eligible

# %%
marks = 85
entry_test = 70

if marks >= 80 and entry_test >= 60:
    print("Admission Granted")
elif marks >= 75 and entry_test >= 80:
    print("Conditional Admission")
else:
    print("Rejected")
# Out:
# Admission Granted

# %%
#llops
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Loop Through String
for ch in "Miksi":
    print(ch)
# Out:
# M
# i
# k
# s
# i

# %%
name="miksi khan"
for ch in name:
  print(ch)
# Out:
# m
# i
# k
# s
# i
#
# k
# h
# a
# n

# %%
#loop in ist
numbers = [10, 20, 30]

for n in numbers:
    print(n)
# Out:
# 10
# 20
# 30

# %%
#index based
nums = [5, 10, 15]
print(len(nums))
for i in range(len(nums)):
    print(i, nums[i])
# Out:
# 3
# 0 5
# 1 10
# 2 15

# %%
#while loop
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
password = ""
while password != "admin123":
    password = input("Enter password: ")
print("Access Granted")
# Out:
# Enter password: kkjh
# Enter password: kkhg
# Enter password: admin123
# Access Granted

# %%
password = ""
limit=0
acces= True
while password != "admin123" and limit<3:
    password = input("Enter password: ")
    limit+=1
    if(limit==3):
      print("access denied limits reached!")
      exit()
print("Access Granted")
# Out:
# Enter password: gkufyuyfu
# Enter password: dyf
# Enter password: dyu
# access denied limits reached!
# Access Granted

# %%
limit = 0

while limit < 3:
    password = input("Enter password: ")
    limit += 1

    if password == "admin123":
        print("Access Granted")
        break
else:
    print("Access denied! Limits reached.")
# Out:
# Enter password: guyuyd
# Enter password: hjddt
# Enter password: ggdg
# Access denied! Limits reached.

# %%
#break, continue, pass
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5):
    pass
    #do nothing place holder to prevant error
    #used when
    """
    When planning large systems:
    def login():
    pass

def register():
    pass
    """
    #or
    """
    if condition:
    pass
else:
    print("Not valid")
    """
